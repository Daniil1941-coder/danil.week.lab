# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniil1941-coder/danil.week.lab/blob/main/daniil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Daniil Pinegin"

# %%
my_enrollment_number = "A1"

# %%
my_hobby = "Playing computer games"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Daniil Pinegin, and my my enrollment number is A1. I like Playing computer games.
